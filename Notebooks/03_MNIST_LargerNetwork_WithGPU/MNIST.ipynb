# %%
""" Convolutional Neural Network.

Build and train a convolutional neural network with TensorFlow.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
"""

from __future__ import division, print_function, absolute_import

import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Training Parameters
learning_rate = 0.001
num_steps = 2000
batch_size = 128
display_step = 10

# Network Parameters
num_input = 784 # MNIST data input (img shape: 28*28)
num_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # MNIST data input is a 1-D vector of 784 features (28*28 pixels)
    # Reshape to match picture format [Height x Width x Channel]
    # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# Construct model
logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)


# Evaluate model
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for step in range(1, num_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: 0.8})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 256 MNIST test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Step 1, Minibatch Loss= 64797.9961, Training Accuracy= 0.047
# Step 10, Minibatch Loss= 20255.3008, Training Accuracy= 0.242
# Step 20, Minibatch Loss= 8045.7075, Training Accuracy= 0.539
# Step 30, Minibatch Loss= 5325.9717, Training Accuracy= 0.664
# Step 40, Minibatch Loss= 4915.7275, Training Accuracy= 0.688
# Step 50, Minibatch Loss= 3655.2349, Training Accuracy= 0.750
# Step 60, Minibatch Loss= 1412.0911, Training Accuracy= 0.875
# Step 70, Minibatch Loss= 3053.9053, Training Accuracy= 0.805
# Step 80, Minibatch Loss= 2138.7598, Training Accuracy= 0.844
# Step 90, Minibatch Loss= 2177.3604, Training Accuracy= 0.859
# Step 100, Minibatch Loss= 1817.4579, Training Accuracy= 0.875
# Step 110, Minibatch Loss= 2220.9038, Training Accuracy= 0.859
# Step 120, Minibatch Loss= 1147.5015, Training Accuracy= 0.898
# Step 130, Minibatch Loss= 1769.2870, Training Accuracy= 0.883
# Step 140, Minibatch Loss= 1453.0128, Training Accuracy= 0.922
# Step 150, Minibatch Loss= 1047.5594, Training Accuracy= 0.922
# Step 160, Minibatch Loss= 1956.1482, Training Accuracy= 0.906
# Step 170, Minibatch Loss= 1718.8727, Training Accuracy= 0.906
# Step 180, Minibatch Loss= 1287.7112, Training Accuracy= 0.914
# Step 190, Minibatch Loss= 985.0565, Training Accuracy= 0.906
# Step 200, Minibatch Loss= 866.1464, Training Accuracy= 0.914
# Step 210, Minibatch Loss= 1549.1838, Training Accuracy= 0.867
# Step 220, Minibatch Loss= 1192.5466, Training Accuracy= 0.898
# Step 230, Minibatch Loss= 1393.0491, Training Accuracy= 0.914
# Step 240, Minibatch Loss= 1249.4329, Training Accuracy= 0.906
# Step 250, Minibatch Loss= 824.2939, Training Accuracy= 0.922
# Step 260, Minibatch Loss= 431.8729, Training Accuracy= 0.938
# Step 270, Minibatch Loss= 1347.9550, Training Accuracy= 0.922
# Step 280, Minibatch Loss= 574.1650, Training Accuracy= 0.922
# Step 290, Minibatch Loss= 436.1859, Training Accuracy= 0.953
# Step 300, Minibatch Loss= 165.0530, Training Accuracy= 0.953
# Step 310, Minibatch Loss= 1253.9858, Training Accuracy= 0.898
# Step 320, Minibatch Loss= 676.2939, Training Accuracy= 0.938
# Step 330, Minibatch Loss= 628.1273, Training Accuracy= 0.961
# Step 340, Minibatch Loss= 616.6613, Training Accuracy= 0.945
# Step 350, Minibatch Loss= 483.3779, Training Accuracy= 0.945
# Step 360, Minibatch Loss= 406.0704, Training Accuracy= 0.938
# Step 370, Minibatch Loss= 391.2397, Training Accuracy= 0.953
# Step 380, Minibatch Loss= 565.8109, Training Accuracy= 0.938
# Step 390, Minibatch Loss= 404.0673, Training Accuracy= 0.938
# Step 400, Minibatch Loss= 584.9712, Training Accuracy= 0.938
# Step 410, Minibatch Loss= 751.7742, Training Accuracy= 0.938
# Step 420, Minibatch Loss= 924.6323, Training Accuracy= 0.906
# Step 430, Minibatch Loss= 622.3158, Training Accuracy= 0.969
# Step 440, Minibatch Loss= 884.1175, Training Accuracy= 0.945
# Step 450, Minibatch Loss= 130.1034, Training Accuracy= 0.977
# Step 460, Minibatch Loss= 861.7369, Training Accuracy= 0.922
# Step 470, Minibatch Loss= 302.2433, Training Accuracy= 0.969
# Step 480, Minibatch Loss= 948.8062, Training Accuracy= 0.945
# Step 490, Minibatch Loss= 677.1681, Training Accuracy= 0.953
# Step 500, Minibatch Loss= 629.1384, Training Accuracy= 0.945
# Step 510, Minibatch Loss= 343.5908, Training Accuracy= 0.953
# Step 520, Minibatch Loss= 525.2254, Training Accuracy= 0.938
# Step 530, Minibatch Loss= 355.9332, Training Accuracy= 0.945
# Step 540, Minibatch Loss= 240.0991, Training Accuracy= 0.953
# Step 550, Minibatch Loss= 367.8583, Training Accuracy= 0.953
# Step 560, Minibatch Loss= 294.5434, Training Accuracy= 0.953
# Step 570, Minibatch Loss= 448.5760, Training Accuracy= 0.922
# Step 580, Minibatch Loss= 400.1807, Training Accuracy= 0.945
# Step 590, Minibatch Loss= 158.7619, Training Accuracy= 0.984
# Step 600, Minibatch Loss= 375.5396, Training Accuracy= 0.953
# Step 610, Minibatch Loss= 118.5133, Training Accuracy= 0.969
# Step 620, Minibatch Loss= 344.1520, Training Accuracy= 0.961
# Step 630, Minibatch Loss= 133.9461, Training Accuracy= 0.984
# Step 640, Minibatch Loss= 369.8002, Training Accuracy= 0.961
# Step 650, Minibatch Loss= 351.8056, Training Accuracy= 0.938
# Step 660, Minibatch Loss= 413.5298, Training Accuracy= 0.969
# Step 670, Minibatch Loss= 59.8203, Training Accuracy= 0.977
# Step 680, Minibatch Loss= 355.0804, Training Accuracy= 0.961
# Step 690, Minibatch Loss= 425.7957, Training Accuracy= 0.961
# Step 700, Minibatch Loss= 114.8220, Training Accuracy= 0.969
# Step 710, Minibatch Loss= 348.6619, Training Accuracy= 0.945
# Step 720, Minibatch Loss= 669.0049, Training Accuracy= 0.930
# Step 730, Minibatch Loss= 208.2147, Training Accuracy= 0.961
# Step 740, Minibatch Loss= 34.7124, Training Accuracy= 0.977
# Step 750, Minibatch Loss= 131.0666, Training Accuracy= 0.984
# Step 760, Minibatch Loss= 433.3207, Training Accuracy= 0.961
# Step 770, Minibatch Loss= 296.6089, Training Accuracy= 0.969
# Step 780, Minibatch Loss= 204.4321, Training Accuracy= 0.977
# Step 790, Minibatch Loss= 386.5287, Training Accuracy= 0.969
# Step 800, Minibatch Loss= 116.1575, Training Accuracy= 0.961
# Step 810, Minibatch Loss= 730.1097, Training Accuracy= 0.945
# Step 820, Minibatch Loss= 265.7873, Training Accuracy= 0.969
# Step 830, Minibatch Loss= 445.9818, Training Accuracy= 0.953
# Step 840, Minibatch Loss= 54.6209, Training Accuracy= 0.984
# Step 850, Minibatch Loss= 909.4023, Training Accuracy= 0.914
# Step 860, Minibatch Loss= 123.9265, Training Accuracy= 0.977
# Step 870, Minibatch Loss= 237.5871, Training Accuracy= 0.969
# Step 880, Minibatch Loss= 190.8921, Training Accuracy= 0.977
# Step 890, Minibatch Loss= 466.3699, Training Accuracy= 0.961
# Step 900, Minibatch Loss= 330.2846, Training Accuracy= 0.969
# Step 910, Minibatch Loss= 486.7636, Training Accuracy= 0.938
# Step 920, Minibatch Loss= 38.4074, Training Accuracy= 0.984
# Step 930, Minibatch Loss= 104.3294, Training Accuracy= 0.992
# Step 940, Minibatch Loss= 223.3571, Training Accuracy= 0.969
# Step 950, Minibatch Loss= 176.8663, Training Accuracy= 0.977
# Step 960, Minibatch Loss= 29.5859, Training Accuracy= 0.977
# Step 970, Minibatch Loss= 425.9823, Training Accuracy= 0.953
# Step 980, Minibatch Loss= 264.4671, Training Accuracy= 0.977
# Step 990, Minibatch Loss= 218.3759, Training Accuracy= 0.961
# Step 1000, Minibatch Loss= 83.0304, Training Accuracy= 0.977
# Step 1010, Minibatch Loss= 112.6577, Training Accuracy= 0.977
# Step 1020, Minibatch Loss= 161.8900, Training Accuracy= 0.969
# Step 1030, Minibatch Loss= 9.5700, Training Accuracy= 0.984
# Step 1040, Minibatch Loss= 127.7805, Training Accuracy= 0.977
# Step 1050, Minibatch Loss= 51.4594, Training Accuracy= 0.992
# Step 1060, Minibatch Loss= 223.5291, Training Accuracy= 0.969
# Step 1070, Minibatch Loss= 150.0799, Training Accuracy= 0.977
# Step 1080, Minibatch Loss= 101.3563, Training Accuracy= 0.961
# Step 1090, Minibatch Loss= 406.6888, Training Accuracy= 0.938
# Step 1100, Minibatch Loss= 192.1274, Training Accuracy= 0.992
# Step 1110, Minibatch Loss= 199.4433, Training Accuracy= 0.953
# Step 1120, Minibatch Loss= 304.5411, Training Accuracy= 0.969
# Step 1130, Minibatch Loss= 99.6314, Training Accuracy= 0.984
# Step 1140, Minibatch Loss= 308.1702, Training Accuracy= 0.930
# Step 1150, Minibatch Loss= 46.4592, Training Accuracy= 0.977
# Step 1160, Minibatch Loss= 621.3416, Training Accuracy= 0.938
# Step 1170, Minibatch Loss= 127.7050, Training Accuracy= 0.969
# Step 1180, Minibatch Loss= 93.3816, Training Accuracy= 0.992
# Step 1190, Minibatch Loss= 56.9670, Training Accuracy= 0.992
# Step 1200, Minibatch Loss= 44.1557, Training Accuracy= 0.977
# Step 1210, Minibatch Loss= 101.1858, Training Accuracy= 0.961
# Step 1220, Minibatch Loss= 382.3661, Training Accuracy= 0.961
# Step 1230, Minibatch Loss= 207.3069, Training Accuracy= 0.961
# Step 1240, Minibatch Loss= 85.4923, Training Accuracy= 0.977
# Step 1250, Minibatch Loss= 137.1846, Training Accuracy= 0.984
# Step 1260, Minibatch Loss= 211.1197, Training Accuracy= 0.984
# Step 1270, Minibatch Loss= 320.9912, Training Accuracy= 0.953
# Step 1280, Minibatch Loss= 376.3537, Training Accuracy= 0.961
# Step 1290, Minibatch Loss= 112.2610, Training Accuracy= 0.977
# Step 1300, Minibatch Loss= 139.9083, Training Accuracy= 0.977
# Step 1310, Minibatch Loss= 29.2508, Training Accuracy= 0.992
# Step 1320, Minibatch Loss= 204.7283, Training Accuracy= 0.969
# Step 1330, Minibatch Loss= 18.7235, Training Accuracy= 0.992
# Step 1340, Minibatch Loss= 196.7529, Training Accuracy= 0.977
# Step 1350, Minibatch Loss= 149.3275, Training Accuracy= 0.969
# Step 1360, Minibatch Loss= 4.8029, Training Accuracy= 0.992
# Step 1370, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1380, Minibatch Loss= 180.8687, Training Accuracy= 0.977
# Step 1390, Minibatch Loss= 102.4807, Training Accuracy= 0.977
# Step 1400, Minibatch Loss= 265.7403, Training Accuracy= 0.969
# Step 1410, Minibatch Loss= 141.3875, Training Accuracy= 0.961
# Step 1420, Minibatch Loss= 61.3694, Training Accuracy= 0.984
# Step 1430, Minibatch Loss= 28.7256, Training Accuracy= 0.984
# Step 1440, Minibatch Loss= 43.4433, Training Accuracy= 0.992
# Step 1450, Minibatch Loss= 60.3837, Training Accuracy= 0.992
# Step 1460, Minibatch Loss= 204.6148, Training Accuracy= 0.945
# Step 1470, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1480, Minibatch Loss= 246.1901, Training Accuracy= 0.953
# Step 1490, Minibatch Loss= 101.2689, Training Accuracy= 0.977
# Step 1500, Minibatch Loss= 173.9280, Training Accuracy= 0.961
# Step 1510, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1520, Minibatch Loss= 118.8818, Training Accuracy= 0.977
# Step 1530, Minibatch Loss= 170.7710, Training Accuracy= 0.984
# Step 1540, Minibatch Loss= 136.8529, Training Accuracy= 0.984
# Step 1550, Minibatch Loss= 17.0773, Training Accuracy= 0.992
# Step 1560, Minibatch Loss= 413.3033, Training Accuracy= 0.969
# Step 1570, Minibatch Loss= 263.9966, Training Accuracy= 0.977
# Step 1580, Minibatch Loss= 185.7420, Training Accuracy= 0.953
# Step 1590, Minibatch Loss= 83.0487, Training Accuracy= 0.992
# Step 1600, Minibatch Loss= 4.5594, Training Accuracy= 0.984
# Step 1610, Minibatch Loss= 34.1668, Training Accuracy= 0.992
# Step 1620, Minibatch Loss= 0.7779, Training Accuracy= 0.992
# Step 1630, Minibatch Loss= 148.1128, Training Accuracy= 0.977
# Step 1640, Minibatch Loss= 71.8076, Training Accuracy= 0.984
# Step 1650, Minibatch Loss= 126.0897, Training Accuracy= 0.984
# Step 1660, Minibatch Loss= 141.9347, Training Accuracy= 0.977
# Step 1670, Minibatch Loss= 43.9675, Training Accuracy= 0.984
# Step 1680, Minibatch Loss= 229.4577, Training Accuracy= 0.961
# Step 1690, Minibatch Loss= 145.1625, Training Accuracy= 0.961
# Step 1700, Minibatch Loss= 128.3710, Training Accuracy= 0.969
# Step 1710, Minibatch Loss= 95.1673, Training Accuracy= 0.984
# Step 1720, Minibatch Loss= 76.2464, Training Accuracy= 0.992
# Step 1730, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1740, Minibatch Loss= 27.9972, Training Accuracy= 0.984
# Step 1750, Minibatch Loss= 2.2280, Training Accuracy= 0.992
# Step 1760, Minibatch Loss= 141.9019, Training Accuracy= 0.984
# Step 1770, Minibatch Loss= 175.9331, Training Accuracy= 0.969
# Step 1780, Minibatch Loss= 60.9807, Training Accuracy= 0.977
# Step 1790, Minibatch Loss= 110.2031, Training Accuracy= 0.961
# Step 1800, Minibatch Loss= 114.4323, Training Accuracy= 0.977
# Step 1810, Minibatch Loss= 195.4489, Training Accuracy= 0.969
# Step 1820, Minibatch Loss= 72.5581, Training Accuracy= 0.992
# Step 1830, Minibatch Loss= 158.1266, Training Accuracy= 0.977
# Step 1840, Minibatch Loss= 130.9248, Training Accuracy= 0.984
# Step 1850, Minibatch Loss= 14.6948, Training Accuracy= 0.992
# Step 1860, Minibatch Loss= 144.3778, Training Accuracy= 0.961
# Step 1870, Minibatch Loss= 12.5752, Training Accuracy= 0.992
# Step 1880, Minibatch Loss= 92.6934, Training Accuracy= 0.984
# Step 1890, Minibatch Loss= 2.0448, Training Accuracy= 0.992
# Step 1900, Minibatch Loss= 84.1841, Training Accuracy= 0.984
# Step 1910, Minibatch Loss= 86.0300, Training Accuracy= 0.984
# Step 1920, Minibatch Loss= 71.0376, Training Accuracy= 0.984
# Step 1930, Minibatch Loss= 157.9575, Training Accuracy= 0.977
# Step 1940, Minibatch Loss= 195.1875, Training Accuracy= 0.977
# Step 1950, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 1960, Minibatch Loss= 72.9386, Training Accuracy= 0.977
# Step 1970, Minibatch Loss= 18.6762, Training Accuracy= 0.992
# Step 1980, Minibatch Loss= 77.0440, Training Accuracy= 0.984
# Step 1990, Minibatch Loss= 0.0895, Training Accuracy= 0.992
# Step 2000, Minibatch Loss= 0.4599, Training Accuracy= 0.992
# Optimization Finished!
# Testing Accuracy: 0.98046875
